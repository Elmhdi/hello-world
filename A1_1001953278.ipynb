# %% [markdown]
# <a href="https://colab.research.google.com/github/Elmhdi/hello-world/blob/main/A1_1001953278.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Queston(1)**

# %%
conv=(1000/3600)
numofmolesA=634
numofmolesB=1131
numofmolesC=70
numofmolesCO2=189

#conversion of the values provided from kmol/hour to moles/second

CO=numofmolesA*conv
H20=numofmolesB*conv
H2=numofmolesC*conv
CO2=numofmolesCO2*conv

#ideal gas law to find volume
Rateconstant=0.08206
temperature=[300,350,400,450]
numberofmoles=[177.50,315.83,52.50,18.06]
pressure=[2,4,6,8]
Ch=['CO','H20','CO2','H2']

for i in range(4):
  volume=numberofmoles[i]*temperature[i]*Rateconstant/pressure[i]
  res=(Ch[i],pressure[i],temperature[i],volume)
  print('Number of moles  %s : pressure = %d , temperature = %d , volume = %0.2f '%res)
# Out:
# Number of moles  CO : pressure = 2 , temperature = 300 , volume = 2184.85
# Number of moles  H20 : pressure = 4 , temperature = 350 , volume = 2267.74
# Number of moles  CO2 : pressure = 6 , temperature = 400 , volume = 287.21
# Number of moles  H2 : pressure = 8 , temperature = 450 , volume = 83.36

# %%
# Redlich-Kwong
# p in range of 1 - 10 atm
# T in range of 300 - 500 k


E = ['CO', 'H20', 'CO2', 'H2' ]
P = int(input('Enter Value of  P'))
T = int(input('Enter Value of  T'))
K = [634, 1131, 189, 70]
R = 8.314

Pc = [34.532, 217.67, 72.865, 12.96]
Tc = [132.9, 647.1, 304.2, 33.19]
E = [0.049, 0.344, 0.225, -0.22]

# REDLICH kWONG Parameters

for i in range(4):
a = (0.427*T*(R**2)*(Tc[i]**2))/Pc[i]
b = 0.0866*R*Tc[i]/pc[i]

for i in range(4):
  V = ((1/p)+(b/R*T))/(1(R*T))-((T**0.5)*b)/a
  res = (E[i], P, T, K[i], V)
  print('Volume for element E %s: m = %s, T = %s, P= %s, V = %s'%res)

# %%
import matplotlib.pyplot as plt
import numpy as np
# x = 1 to 10 atm
# y = 300 to 500 K
x = np.linspace(0,1,10)
y = np.linspace(300,400,500)

y = [34.532, 217.67, 72.865, 12.96]
x = [132.9, 647.1, 304.2, 33.19]
z = [634, 1131, 189, 70]

plt.plot(x,y,z)
plt.plot(x,y,z)
plt.xlabel('temperature X')
plt.ylabel('pressure Y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# x = 1 to 10 atm
# y = 300 to 500 K
x = np.linspace(0,1,10)
y = np.linspace(300,400,500)

y = [34.532, 217.67, 72.865, 12.96]
x = [2184.85, 2267.74, 287.21, 83.36]
z = [634, 1131, 189, 70]

plt.plot(x,y,z)
plt.plot(x,y,z)
plt.xlabel('pressure Y')
plt.ylabel('Volume X')
plt.show()

# %%
 import matplotlib.pyplot as plt
 pressuer=[2,4,6,8]
 temperature=[300,350,400,450]
 plt.plot(pressuer,temperature)
 plt.show()

# %% [markdown]
# **Question(2)**

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

pi=3.14159
degrees2radian=(59*pi)/180
tan_radian=math.tan(degrees2radian)
cos_radian=math.cos(degrees2radian)

g=9.81
v=28
y1=0.64

x= np.linspace(0,50, 100)
y=((tan_radian)*x)-(((g)/(2*(v**2)*(cos_radian**2)))*(x**2))+y1

plt.plot(x,y)
plt.xlabel("Disatnce(X)")
plt.ylabel("Height(Y)")
plt.show()

# %%
import matplotlib.pyplot as plt
import math

import numpy as np

pi=3.14
degrees2radian=(59*pi)/180
tan_radian=math.tan(degrees2radian)
cos_radian=math.cos(degrees2radian)

g=9.81
v=28
y1=0.64

x1= np.linspace(0,50, 100)
y1= ((tan_radian)*x)-(((g)/(2*(v**2)*(cos_radian**2)))*(x**2))+y1

plt.plot(x1,y1,label="with angle as 50")

pi=3.14
degrees2radian=(58*pi)/180
tan_radian=math.tan(degrees2radian)
cos_radian=math.cos(degrees2radian)

g=9.81
v=28
y1=0.64

x2= np.linspace(0,50, 100)
y2=((tan_radian)*x)-(((g)/(2*(v**2)*(cos_radian**2)))*(x**2))+y1

plt.plot(x2,y2,label="with angle as 56")

pi=3.14159
degrees2radian=(60*pi)/180
tan_radian=math.tan(degrees2radian)
cos_radian=math.cos(degrees2radian)

g=9.81
v=28
y1=0.64

x1= np.linspace(0,50, 100)
y1=((tan_radian)*x)-(((g)/(2*(v**2)*(cos_radian**2)))*(x**2))+y1

plt.plot(x1,y1,label="with angle as 66")

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.xlabel("Theita(X)")
plt.ylabel("Height(Y)")
plt.show()
